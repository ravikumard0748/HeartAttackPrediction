# %%
import pandas as pd

# %%
df=pd.read_csv("../datas/final_heart_datas.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex  Cholesterol  Heart Rate  Diabetes  Family History  \
# 0           0   67    1          208          72         0               0
# 1           1   21    1          389          98         1               1
# 2           2   21    0          324          72         1               0
# 3           3   84    1          383          73         1               1
# 4           4   66    1          318          93         1               1
#
#    Smoking  Obesity  Alcohol Consumption  ...  Stress Level  \
# 0        1        0                    0  ...             9
# 1        1        1                    1  ...             1
# 2        0        0                    0  ...             9
# 3        1        0                    1  ...             9
# 4        1        1                    0  ...             6
#
#    Sedentary Hours Per Day  Income        BMI  Triglycerides  \
# 0                 6.615001  261404  31.251233            286
# ...
